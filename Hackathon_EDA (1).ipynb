# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %% [markdown]
# ## Importing the data

# %%
df = pd.read_csv("/content/predictions.csv")

# %%
df.head()
# Out:
#    age         job  marital  education default  balance housing loan  \
# 0   57     retired  married  secondary      no      718      no   no
# 1   50  management  married  secondary      no      268      no   no
# 2   46  technician   single  secondary      no     4367     yes   no
# 3   56      admin.  married  secondary      no     3554      no   no
# 4   32    services   single   tertiary      no      785      no   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular    3   jun       170         1     -1         0  unknown  no
# 1  cellular    3   jun        74         2     90         2  failure  no
# 2  cellular    3   jun        65         1     96         1  failure  no
# 3  cellular    3   jun       151         1     -1         0  unknown  no
# 4  cellular    3   jun       273         1     -1         0  unknown  no

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Missing Values

# %%
df.isna().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %% [markdown]
# ## Duplicate Values

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Ensuring appropriate data types for every column

# %%
df.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %% [markdown]
# # Data analysis

# %% [markdown]
# ## Summary for numerical columns

# %%
df.describe()
# Out:
#                age       balance          day     duration     campaign  \
# count  5211.000000   5211.000000  5211.000000  5211.000000  5211.000000
# mean     43.942238   2037.724045    14.188256   283.791787     1.855498
# std      15.954058   3898.173799     8.483453   241.441834     1.343656
# min      18.000000  -1206.000000     1.000000     1.000000     1.000000
# 25%      31.000000    270.500000     7.000000   134.500000     1.000000
# 50%      39.000000    889.000000    13.000000   220.000000     1.000000
# 75%      56.000000   2346.500000    21.000000   355.000000     2.000000
# max      95.000000  81204.000000    31.000000  3785.000000    16.000000
#
#              pdays     previous
# count  5211.000000  5211.000000
# mean    103.462099     1.829783
# std     137.157167     2.985956
# min      -1.000000     0.000000
# 25%      -1.000000     0.000000
# 50%      87.000000     1.000000
# 75%     181.000000     3.000000
# max     871.000000    55.000000

# %% [markdown]
# ## Summary for categorical columns

# %%
df.describe(include='object')
# Out:
#                job  marital  education default housing  loan   contact month  \
# count         5211     5211       5211    5211    5211  5211      5211  5211
# unique          12        3          4       2       2     2         3    12
# top     management  married  secondary      no      no    no  cellular   aug
# freq          1292     2828       2209    5205    4112  4897      4371  1032
#
#        poutcome     y
# count      5211  5211
# unique        4     2
# top     unknown    no
# freq       2352  4544

# %% [markdown]
# ## Distribution of age

# %%
# Define a function to categorize age
def age_grouping(age):
    if age < 30:
        return '<30'
    elif 30 <= age <= 50:
        return '30-50'
    else:
        return '>50'

df['age_group'] = df['age'].apply(age_grouping)

# %%
distribution_age=df.groupby(['age_group','y']).size().unstack().reindex(["<30","30-50",">50"])
distribution_age
# Out:
# y            no  yes
# age_group
# <30         862  137
# 30-50      2275  234
# >50        1407  296

# %% [markdown]
# ## Distribution across job types

# %%
distribution_job = df.groupby(['job','y']).size().unstack()
distribution_job
# Out:
# y                no  yes
# job
# admin.          617   71
# blue-collar     314   35
# entrepreneur     78    4
# housemaid       138   15
# management     1139  153
# retired         640  187
# self-employed   151   14
# services        220   24
# student         361   53
# technician      666   79
# unemployed      172   27
# unknown          48    5

# %% [markdown]
# ## Distribution across marital status

# %%
distribution_marital = df.groupby(['marital','y']).size().unstack()
distribution_marital
# Out:
# y           no  yes
# marital
# divorced   400   82
# married   2486  342
# single    1658  243

# %% [markdown]
# ## Distribution across education

# %%
distribution_education = df.groupby(['education','y']).size().unstack()
distribution_education
# Out:
# y            no  yes
# education
# primary     478  103
# secondary  1920  289
# tertiary   1844  251
# unknown     302   24

# %% [markdown]
# ## Distribution depending on the outcome

# %%
distribution_outcome = df.groupby(['poutcome','y']).size().unstack()
distribution_outcome
# Out:
# y           no  yes
# poutcome
# failure   1064  107
# other      452   58
# success    955  223
# unknown   2073  279

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ##
61,37,80,53,80,61,35,58,30,50,21,46,65,32,67,57,46,40,29,53,44,74,38,73,65,62,65,67,66,34,67,34,57,38,47,71,56,46,59,57,66,47,30,32,69,32,72,63,41,72,59,45,33,37,26,29,32,77,57,79,37,37,25,49,32,34,44,26,25,49,42,58,47,73,33,34,57,35,55,71,41,23,60,18,63,60,47,27,37,27,33,18,39,46,30,65,54,42,33,32,59,38,48,22,59,28,80,46,32,33,61,40,52,71,40,26,30,62,50,32,23,70,55,33,31,26,30,44,23,63,45,37,68,83,31,34,71,57,55,73,42,64,34,24,33,42,42,42,29,20,22,28,55,40,70,57,60,53,31,48,30,60,61,78,32,31,37,39,20,21,34,42,26,29,33,46,40,29,45,55,39,55,58,24,72,81,42,42,32,23,81,57,70,36,33,40,64,27,71,66,60,32,32,37,44,26,25,26,31,32,21,74,35,24,28,50,36,59,38,75,20,36,35,57,40,41,59,30,28,53,37,36,47,61,18,32,51,37,37,34,34,43,35,82,32,36,43,58,64,55,35,58,26,33,69,33,23,80,57,34,76,49,69,32,43,33,46,30,64,44,49,53,34,25,19,44,46,26,50,74,30,26,31,36,40,30,32,35,32,43,62,70,61,43,74,45,38,47,32,38,52,77,58,67,71,32,32,32,29,40,26,31,30,69,29,36,50,51,44,71,67,26,36,66,37,77,60,33,33,23,34,56,39,33,76,72,37,28,24,24,66,42,33,29,21,33,35,28,34,27,35,48,34,54,74,36,48,26,45,57,34,34,30,56,35,50,30,45,36,57,35,30,34,30,33,33,66,49,29,49,33,58,37,74,67,37,35,59,68,21,57,2 ...

# %% [markdown]
# ## Distribution of type of jobs

# %%
fig = px.bar(df['job'].value_counts(),
             title="Distribution of Job Types",
             labels={'job':'Job','value':'Count'})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="cc4d7778-2d8f-49f7-b273-ca11959f1281" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cc4d7778-2d8f-49f7-b273-ca11959f1281")) {                    Plotly.newPlot(                        "cc4d7778-2d8f-49f7-b273-ca11959f1281",                        [{"alignmentgroup":"True","hovertemplate":"variable=count\u003cbr\u003eJob=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"count","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"count","offsetgroup":"count","orientation":"v","showlegend":true,"textposition":"auto","x":["management","retired","technician","admin.","student","blue-collar","services","unemployed","self-employed","housemaid","entrepreneur","unknown"],"xaxis":"x","y":[1292,827,745,688,414,349,244,199,165,153,82,53],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"colo ...

# %% [markdown]
# ## Balance Distribution by the Target Prediction

# %%
fig = px.box(df,
             x='y', y='balance',
             color='y',
             title='Balance Distribution by the Target Prediction',
             labels={'y':'Target Prediction','balance':'Balance'},
             height=1200)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5ef433fd-aaa8-4e3e-a4f4-ae87c44057b0" class="plotly-graph-div" style="height:1200px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5ef433fd-aaa8-4e3e-a4f4-ae87c44057b0")) {                    Plotly.newPlot(                        "5ef433fd-aaa8-4e3e-a4f4-ae87c44057b0",                        [{"alignmentgroup":"True","hovertemplate":"Target Prediction=%{x}\u003cbr\u003eBalance=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"no","marker":{"color":"#636efa"},"name":"no","notched":false,"offsetgroup":"no","orientation":"v","showlegend":true,"x":["no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","no","n ...

# %% [markdown]
# ## Distribution of Job types and Prediction

# %%
fig = px.bar(distribution_job,
             x=distribution_job.index,
             y=distribution_job.columns,
             barmode="group",
             title="Job Distribution for Target Prediction",
             labels={'job':'Job','value':"Count",'y':'Prediction'})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="cf1fa6b6-6ba6-48b9-b742-c6226fcc8818" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cf1fa6b6-6ba6-48b9-b742-c6226fcc8818")) {                    Plotly.newPlot(                        "cf1fa6b6-6ba6-48b9-b742-c6226fcc8818",                        [{"alignmentgroup":"True","hovertemplate":"Prediction=no\u003cbr\u003eJob=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"no","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"no","offsetgroup":"no","orientation":"v","showlegend":true,"textposition":"auto","x":["admin.","blue-collar","entrepreneur","housemaid","management","retired","self-employed","services","student","technician","unemployed","unknown"],"xaxis":"x","y":[617,314,78,138,1139,640,151,220,361,666,172,48],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Prediction=yes\u003cbr\u003eJob=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"yes","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"yes","offsetgroup":"yes","orientation":"v","showlegend":true,"textposition":"auto","x":["admin.","blue-collar","entrepreneur","housemaid","management","retired","self-employed","services","student","technician","unemployed","unknown"],"xaxis":"x","y":[71,35,4,15,153,187,14,24,53,79,27,5],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666 ...

# %% [markdown]
# ## Distribution of Age groups

# %%
fig = px.bar(distribution_age,
             x=distribution_age.index,
             y=distribution_age.columns,
             barmode="group",
             title="Agee Distribution for Target Prediction",
             labels={'age_group':'Age Groups','value':"Count",'y':'Prediction'})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="363eec48-2469-454f-95a5-5038c4531f93" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("363eec48-2469-454f-95a5-5038c4531f93")) {                    Plotly.newPlot(                        "363eec48-2469-454f-95a5-5038c4531f93",                        [{"alignmentgroup":"True","hovertemplate":"Prediction=no\u003cbr\u003eAge Groups=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"no","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"no","offsetgroup":"no","orientation":"v","showlegend":true,"textposition":"auto","x":["\u003c30","30-50","\u003e50"],"xaxis":"x","y":[862,2275,1407],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Prediction=yes\u003cbr\u003eAge Groups=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"yes","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"yes","offsetgroup":"yes","orientation":"v","showlegend":true,"textposition":"auto","x":["\u003c30","30-50","\u003e50"],"xaxis":"x","y":[137,234,296],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type ...

# %% [markdown]
# ## Age vs Balance

# %%
fig = px.scatter(df,
                 x='age', y='balance',
                 color='y',
                 title='Age vs Balance by Prediction Status',
                 labels={'age':'Age','balance':'Balance','y':'Prediction'})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="25999822-a50f-46db-8bf3-247442f7943c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("25999822-a50f-46db-8bf3-247442f7943c")) {                    Plotly.newPlot(                        "25999822-a50f-46db-8bf3-247442f7943c",                        [{"hovertemplate":"Prediction=no\u003cbr\u003eAge=%{x}\u003cbr\u003eBalance=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"no","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"no","showlegend":true,"x":[57,50,46,56,32,39,39,37,29,30,44,46,36,33,57,55,22,39,27,40,34,41,56,41,25,58,36,39,33,44,55,33,38,29,40,22,46,43,46,30,34,35,37,42,42,36,37,27,33,29,36,29,34,26,39,48,41,29,33,40,32,26,43,30,30,38,55,25,38,41,35,31,25,44,22,34,38,24,24,38,34,50,58,32,27,34,30,44,29,27,40,60,50,28,57,41,31,27,29,60,54,20,23,22,25,28,58,57,44,25,31,33,26,40,34,57,25,21,36,54,59,28,28,24,55,53,30,35,30,25,59,35,38,31,42,21,34,35,41,26,55,30,28,31,31,48,31,25,53,39,38,51,33,36,33,54,54,50,36,36,28,56,50,35,37,50,52,46,31,38,53,49,51,34,33,35,35,25,31,31,31,43,50,41,50,25,37,31,52,41,42,30,30,25,40,60,29,30,49,48,26,23,60,22,28,47,40,50,34,34,54,31,51,33,25,32,54,29,24,60,32,25,52,33,34,26,25,26,56,55,36,47,28,58,31,43,25,35,31,27,26,23,31,37,46,35,35,39,28,39,27,45,28,46,27,49,24,60,35,26,37,34,28,33,30,20,31,29,44,28,25,23,53,27,30,55,50,22,24,27,48,29,48,58,32,26,49,27,32,21,35,24,37,43,31,57,39,34,57,42,58,34,26,42,49,28,23,31,50,26,57,35,59,55,27,54,32,30,83,31,43,61,73,26,58,37,37,79,19,48,27,71,63,71,61,52,54,45,33,80,44,45,37,22,44,35,
# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y', 'age_group'],
#       dtype='object')

# %% [markdown]
# ## Correlation

# %%
object_cols=['job','marital','education','default','housing','loan','contact','month','poutcome','y','age_group']

temp_df = df.copy()
# dropping obj type columns
temp_df = temp_df.drop(columns=object_cols)

bounds = {}
for col in temp_df.columns:
    q1 = np.quantile(temp_df[col], 0.25)
    q3 = np.quantile(temp_df[col], 0.75)
    iqr = q3 - q1
    bounds[col] = (q1 - 1.5 * iqr, q3 + 1.5 * iqr)

for col, (lb, ub) in bounds.items():
    temp_df = temp_df[(temp_df[col] >= lb) & (temp_df[col] <= ub)]

corr_matrix = temp_df.corr()
corr_matrix
# Out:
#                age   balance       day  duration  campaign     pdays  previous
# age       1.000000  0.130447  0.041742  0.113613  0.021113 -0.019033  0.000312
# balance   0.130447  1.000000  0.023278  0.083564  0.050662  0.041109  0.027864
# day       0.041742  0.023278  1.000000 -0.022639  0.041599  0.054840 -0.002154
# duration  0.113613  0.083564 -0.022639  1.000000  0.043934  0.079722  0.071178
# campaign  0.021113  0.050662  0.041599  0.043934  1.000000  0.027889  0.032568
# pdays    -0.019033  0.041109  0.054840  0.079722  0.027889  1.000000  0.525227
# previous  0.000312  0.027864 -0.002154  0.071178  0.032568  0.525227  1.000000

# %%
fig = px.imshow(corr_matrix,
                text_auto=".2f",
                labels={'color':'Correlationship'},
                color_continuous_scale="teal",)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2a929cc0-107a-42b3-bb0e-e85696e7d819" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2a929cc0-107a-42b3-bb0e-e85696e7d819")) {                    Plotly.newPlot(                        "2a929cc0-107a-42b3-bb0e-e85696e7d819",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z:.2f}","x":["age","balance","day","duration","campaign","pdays","previous"],"y":["age","balance","day","duration","campaign","pdays","previous"],"z":[[1.0,0.1304474968528718,0.04174183780246473,0.11361270251053025,0.02111318273345977,-0.019032522094986248,0.0003124595708689508],[0.1304474968528718,1.0,0.023278227774181173,0.08356410673893234,0.05066236661441123,0.041108967042575,0.02786416691301425],[0.04174183780246473,0.023278227774181173,1.0,-0.022639359303718933,0.041599015354384504,0.05484026854842573,-0.0021544159596024325],[0.11361270251053025,0.08356410673893234,-0.022639359303718933,1.0,0.04393427698407135,0.07972169463632164,0.07117835396229275],[0.02111318273345977,0.05066236661441123,0.041599015354384504,0.04393427698407135,1.0,0.027888751964716015,0.03256819279523171],[-0.019032522094986248,0.041108967042575,0.05484026854842573,0.07972169463632164,0.027888751964716015,1.0,0.5252271704101368],[0.0003124595708689508,0.02786416691301425,-0.0021544159596024325,0.07117835396229275,0.03256819279523171,0.5252271704101368,1.0]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}\u003cbr\u003ey: %{y}\u003cbr\u003eCorrelationship: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"# ...

# %% [markdown]
# ## Time-Anal

# %%
monthly=df.groupby(['month','y']).size().unstack().reindex(
    ['jan','feb','mar','apr','may','jun','jul','aug','sep','oct','nov','dec'])

fig = px.line(monthly,
              color='y',
              title="Prediction Distribution by Month",
              labels={'month':'Month','value':'Count','y':'Prediction'})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1a8db187-970d-42f4-b3dc-6ec37ab91fe6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1a8db187-970d-42f4-b3dc-6ec37ab91fe6")) {                    Plotly.newPlot(                        "1a8db187-970d-42f4-b3dc-6ec37ab91fe6",                        [{"hovertemplate":"Prediction=no\u003cbr\u003eMonth=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"no","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"no","orientation":"v","showlegend":true,"x":["jan","feb","mar","apr","may","jun","jul","aug","sep","oct","nov","dec"],"xaxis":"x","y":[218,302,116,181,209,522,491,984,537,450,354,180],"yaxis":"y","type":"scatter"},{"hovertemplate":"Prediction=yes\u003cbr\u003eMonth=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"yes","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"yes","orientation":"v","showlegend":true,"x":["jan","feb","mar","apr","may","jun","jul","aug","sep","oct","nov","dec"],"xaxis":"x","y":[9,51,103,33,25,85,24,48,42,208,18,21],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmo ...

# %%
df.to_csv("prediction_data.csv")
